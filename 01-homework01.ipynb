# %% [markdown]
# # Домашнее задание № 1: Знакомство с Python
#
# Задание направлено на знакомство с языком программирования Python на основе открытых образовательных материалов.
#
# ## Общее для домашних заданий
# Можно пользоваться любыми другими ресурсами, обучающими курсами и книгами по выбору студента. Не возбраняется использовать и главный инструмент любого программиста — поисковый запрос, хотя в целом рекомендуется обучающие примеры и задачи решать сперва самостоятельно. И только после возникновения неразрешимых трудностей или же нюансов, которые начинают объективно отнимать много времени, уже обращаться за помощью к кладезю мировых знаний — Интернету.
#
# Что не рекомендуется на этапе выполнения домашних заданий, так это обращаться за помощью к своим товарищам по группе и курсу. Для командной работы в конце семестра нас ожидает хакатон, а домашние задания — сугубо индивидуальная штука.

# %% [markdown]
# ## Обучающие материалы
#
# Для знакомства с базовыми основами программирования на языке Python необходимо последовательно освоить следующие материалы. Рекомендуется выполнять абсолютно все задания в конце каждого из уроков.
#
# 1. Знакомство: https://younglinux.info/python/introductionpython
# 2. Типы данных: https://younglinux.info/python/variable
# 3. Ввод/вывод: https://younglinux.info/python/input
# 4. Логические выражения: https://younglinux.info/python/operators
# 5. Условный оператор if: https://younglinux.info/python/if
# 6. Ошибки и исключения: https://younglinux.info/python/exceptions
# 7. Функции:
#     * https://younglinux.info/python/function
#     * https://younglinux.info/python/local-global
#     * https://younglinux.info/python/return
#     * https://younglinux.info/python/arguments
#     * https://younglinux.info/python/builtin-functions
# 8. Модули (импортирование библиотек): https://younglinux.info/python/modules
#
# Вы можете изучить и другие разделы курса при желании.

# %% [markdown]
# ## Прямая геодезическая задача
#
# Напишите функцию для решения **прямой** геодезической задачи на плоскости. На вход подаются плоские координаты $(x_1, y_1)$ исходного пункта, дирекционный угол $\alpha_{12}$ и расстояние $s_{12}$. Требуется вычислить плоские координаты $(x_2, y_2)$ определяемого пункта.

# %%
def direct_geodesic_problem():
    ...

# %% [markdown]
# ## Обратная геодезическая задача
#
# Напишите функцию для решения **обратной** геодезической задачи. На вход подаются плоские координаты $(x_1, y_1)$ и $(x_2, y_2)$ двух точек. Необходимо найти расстояние $s_{12}$ между ними и дирекционный угол $\alpha_{12}$ этого направления.

# %%
def inverse_geodesic_problem():
    ...

# %% [markdown]
# ## Контрольные вычисления
#
# При разработке даже простой программы (или её части) необходимо понимать и контролировать, что именно должно получаться в результате её исполнения. Для этого обычно пишутся тесты, то есть части кода, главной задачей которых является определение корректности работы основной программы или её частей. Мы в нашем курсе написанием тестов заниматься не будем, но проверять корректность своих вычислений — задача любого уважающего себя инженера или учёного. Поэтому делаем следующее.
#
# ### С разными вариантами корректных исходных данных
#
# Придумайте тестовые наборы исходных данных для прямой и обратной геодезической задачи таким образом, чтобы они покрывали все возможные случаи входных данных. Например, обязательно стоит предусмотреть, чтобы дирекционный угол лежал в разных квадрантах и на пересечения с осями системы координат. На всех указанных данных применить разработанные функции для решения прямой и обратной задачи и убедиться, что получается одинаковый результат. Все вычисления вывести внутри этого Jupyter Notebook.

# %%
# Здесь тестовые данные (можно несколько ячеек задействовать для наглядности). 
# Каждый тестовый набор необходимо сопровождать поясняющим комментарием (какой случай он покрывает?)

# %% [markdown]
# ### С разными вариантами некорректных исходных данных
#
# Придумайте ошибочные данные, которые пользователь может ввести в написанные вами функции. Очевидно, что они могут исказить результат вычислений, либо прервать процесс вычисления с ошибкой. Один из простых способов борьбы с этим  — проверка корректности входных данных внутри функции до начала запуска её основной части. Модифицируйте свои функции для поддержки такой проверки.
#
# На всех ошибочных данных применить разработанные функции для решения прямой и обратной задачи и убедиться, что они возвращают заранее предусмотренную ошибку и прекращают работу. Все вычисления вывести внутри этого Jupyter Notebook.

# %%
# Здесь тестовые данные (можно несколько ячеек задействовать)
# Каждый тестовый набор необходимо сопровождать поясняющим комментарием (какой случай он покрывает?)
